# %% [markdown]
# # UFCFVQ-15-M Programming for Data Science (Spring 2022)
# # Programming Task 2
#
# ## Student Id:

# %% [markdown]
# ### Requirement FR9 - Read CSV data from two files and merge it into a single Data Frame

# %%
# import pandas to read the the csv file using .read_csv function. The next things is to merge the  data and not  
import pandas as pd
# add code here
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import datetime

# %%
task2a_df = pd.read_csv('task2a.csv')   # Reads in the 2a data frame directly the way it is from memory
task2a_df                               # load/Display the data frame
# Out:
#               timestamp  new_bike_shares
# 0      04/01/2015 00:00              182
# 1      04/01/2015 01:00              138
# 2      04/01/2015 02:00              134
# 3      04/01/2015 03:00               72
# 4      04/01/2015 04:00               47
# ...                 ...              ...
# 17409  03/01/2017 19:00             1042
# 17410  03/01/2017 20:00              541
# 17411  03/01/2017 21:00              337
# 17412  03/01/2017 22:00              224
# 17413  03/01/2017 23:00              139
#
# [17414 rows x 2 columns]

# %%
task2a_df.dtypes
# Out:
# timestamp          object
# new_bike_shares     int64
# dtype: object

# %%
task2b_df = pd.read_csv("task2b.csv")   # Reads in the 2b data frame directly the way it is from memory
task2b_df                               # loads the data frame
# Out:
#               timestamp  temperature  feels_like_temp  humidity  wind_speed  \
# 0      04/01/2015 00:00          3.0              2.0      93.0         6.0
# 1      04/01/2015 01:00          3.0              2.5      93.0         5.0
# 2      04/01/2015 02:00          2.5              2.5      96.5         0.0
# 3      04/01/2015 03:00          2.0              2.0     100.0         0.0
# 4      04/01/2015 04:00          2.0              0.0      93.0         6.5
# ...                 ...          ...              ...       ...         ...
# 17409  03/01/2017 19:00          5.0              1.0      81.0        19.0
# 17410  03/01/2017 20:00          5.0              1.0      81.0        21.0
# 17411  03/01/2017 21:00          5.5              1.5      78.5        24.0
# 17412  03/01/2017 22:00          5.5              1.5      76.0        23.0
# 17413  03/01/2017 23:00          5.0              1.0      76.0        22.0
#
#        is_weekend  season_code
# 0               1            3
# 1               1            3
# 2               1            3
# 3               1            3
# 4               1            3
# ...           ...          ...
# 17409           0            3
# 17410           0            3
# 17411           0            3
# 17412           0            3
# 17413           0            3
#
# [17414 rows x 7 columns]

# %%
##merge the two files into a single Data Frame
task2merge_df = pd.merge(task2a_df, task2b_df,on="timestamp")
task2merge_df 
#task2merge_df.dtypes
# Out:
#               timestamp  new_bike_shares  temperature  feels_like_temp  \
# 0      04/01/2015 00:00              182          3.0              2.0
# 1      04/01/2015 01:00              138          3.0              2.5
# 2      04/01/2015 02:00              134          2.5              2.5
# 3      04/01/2015 03:00               72          2.0              2.0
# 4      04/01/2015 04:00               47          2.0              0.0
# ...                 ...              ...          ...              ...
# 17409  03/01/2017 19:00             1042          5.0              1.0
# 17410  03/01/2017 20:00              541          5.0              1.0
# 17411  03/01/2017 21:00              337          5.5              1.5
# 17412  03/01/2017 22:00              224          5.5              1.5
# 17413  03/01/2017 23:00              139          5.0              1.0
#
#        humidity  wind_speed  is_weekend  season_code
# 0          93.0         6.0           1            3
# 1          93.0         5.0           1            3
# 2          96.5         0.0           1            3
# 3         100.0         0.0           1            3
# 4          93.0         6.5           1            3
# ...         ...         ...         ...          ...
# 17409      81.0        19.0           0            3
# 17410      81.0        21.0           0            3
# 17411      78.5        24.0           0            3
# 17412      76.0        23.0           0            3
# 17413      76.0        22.0           0            3
#
# [17414 rows x 8 columns]

# %% [markdown]
# <p style="color:red; font-weight:bold; font-size:xx-small">MARK: __%</p>
# <p style="color:red; font-weight:bold; font-size:xx-small">FEEDBACK: </p>

# %% [markdown]
# ### Requirement FR10 - Clean the merged data

# %%
# cleaning this data removes redundant columns like 'season_code' as well as irrelevant figures like numbers less than 20

#task2merge_df.isnull().sum()                  #gets the total number of null values in each columns 

task2merge_df=task2merge_df.dropna.(how='any') #(How = any) means we didn't pass any argument in dropna() 
                                              #then it will delete all the rows with ANY NaN or missing value.
    
#task2merge_df.dtypes                          #check the data type of all columns in the DataFrame

# %%
task2merge_df= task2merge_df.drop(columns="season_code")        #removes/drops the specified columns like 'season_code'
task2merge_df
# Out:
#               timestamp  new_bike_shares  temperature  feels_like_temp  \
# 0      04/01/2015 00:00              182          3.0              2.0
# 1      04/01/2015 01:00              138          3.0              2.5
# 2      04/01/2015 02:00              134          2.5              2.5
# 3      04/01/2015 03:00               72          2.0              2.0
# 4      04/01/2015 04:00               47          2.0              0.0
# ...                 ...              ...          ...              ...
# 17409  03/01/2017 19:00             1042          5.0              1.0
# 17410  03/01/2017 20:00              541          5.0              1.0
# 17411  03/01/2017 21:00              337          5.5              1.5
# 17412  03/01/2017 22:00              224          5.5              1.5
# 17413  03/01/2017 23:00              139          5.0              1.0
#
#        humidity  wind_speed  is_weekend
# 0          93.0         6.0           1
# 1          93.0         5.0           1
# 2          96.5         0.0           1
# 3         100.0         0.0           1
# 4          93.0         6.5           1
# ...         ...         ...         ...
# 17409      81.0        19.0           0
# 17410      81.0        21.0           0
# 17411      78.5        24.0           0
# 17412      76.0        23.0           0
# 17413      76.0        22.0           0
#
# [17414 rows x 7 columns]

# %%
#Remove all rows from the merged data whose new_bike_shares is less than 20 and 
#returns all the rows in the data frame where new_bike_shares is great or equal to 20


task2merge_df= task2merge_df[task2merge_df.new_bike_shares>=20]     
task2merge_df
# Out:
#               timestamp  new_bike_shares  temperature  feels_like_temp  \
# 0      04/01/2015 00:00              182          3.0              2.0
# 1      04/01/2015 01:00              138          3.0              2.5
# 2      04/01/2015 02:00              134          2.5              2.5
# 3      04/01/2015 03:00               72          2.0              2.0
# 4      04/01/2015 04:00               47          2.0              0.0
# ...                 ...              ...          ...              ...
# 17409  03/01/2017 19:00             1042          5.0              1.0
# 17410  03/01/2017 20:00              541          5.0              1.0
# 17411  03/01/2017 21:00              337          5.5              1.5
# 17412  03/01/2017 22:00              224          5.5              1.5
# 17413  03/01/2017 23:00              139          5.0              1.0
#
#        humidity  wind_speed  is_weekend
# 0          93.0         6.0           1
# 1          93.0         5.0           1
# 2          96.5         0.0           1
# 3         100.0         0.0           1
# 4          93.0         6.5           1
# ...         ...         ...         ...
# 17409      81.0        19.0           0
# 17410      81.0        21.0           0
# 17411      78.5        24.0           0
# 17412      76.0        23.0           0
# 17413      76.0        22.0           0
#
# [17373 rows x 7 columns]

# %% [markdown]
# <p style="color:red; font-weight:bold; font-size:xx-small">MARK: __%</p>
# <p style="color:red; font-weight:bold; font-size:xx-small">FEEDBACK: </p>

# %% [markdown]
# ### Requirement FR11 - Investigate the distribution of bike shares by time of the day

# %%
task2merge_df['timestamp'] = pd.to_datetime(task2merge_df['timestamp'])  #convert timestamp to dateTime function   
task2merge_df
# Out:
# <ipython-input-56-a0062bc7f91f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   task2merge_df['timestamp'] = pd.to_datetime(task2merge_df['timestamp'])  #convert timestamp to dateTime function
#                 timestamp  new_bike_shares  temperature  feels_like_temp  \
# 0     2015-04-01 00:00:00              182          3.0              2.0
# 1     2015-04-01 01:00:00              138          3.0              2.5
# 2     2015-04-01 02:00:00              134          2.5              2.5
# 3     2015-04-01 03:00:00               72          2.0              2.0
# 4     2015-04-01 04:00:00               47          2.0              0.0
# ...                   ...              ...          ...              ...
# 17409 2017-03-01 19:00:00             1042          5.0              1.0
# 17410 2017-03-01 20:00:00              541          5.0              1.0
# 17411 2017-03-01 21:00:00              337          5.5              1.5
# 17412 2017-03-01 22:00:00              224          5.5              1.5
# 17413 2017-03-01 23:00:00              139          5.0              1.0
#
#        humidity  wind_speed  is_weekend
# 0          93.0         6.0           1
# 1          93.0         5.0           1
# 2          96.5         0.0           1
# 3         100.0         0.0           1
# 4          93.0         6.5           1
# ...         ...         ...         ...
# 17409      81.0        19.0           0
# 17410      81.0        21.0           0
# 17411      78.5        24.0           0
# 17412      76.0        23.0           0
# 17413      76.0        22.0           0
#
# [17373 rows x 7 columns]

# %%
#create new columns for Hour, Day,month and year
task2merge_df['Year'] = task2merge_df['timestamp'].apply(lambda t: t.year)
task2merge_df['Month'] = task2merge_df['timestamp'].apply(lambda time: time.month)
task2merge_df['Day_of_Week'] = task2merge_df['timestamp'].apply(lambda time: time.dayofweek)
#task2merge_df['Day'] = task2merge_df['timestamp'].apply(lambda t: t.day)
task2merge_df['Hour'] = task2merge_df['timestamp'].apply(lambda time: time.hour)
task2merge_df
# Out:
# <ipython-input-90-727d095ede5d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   task2merge_df['Year'] = task2merge_df['timestamp'].apply(lambda t: t.year)
# <ipython-input-90-727d095ede5d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   task2merge_df['Month'] = task2merge_df['timestamp'].apply(lambda time: time.month)
# <ipython-input-90-727d095ede5d>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   task2merge_df['Day_of_Week'] = task2merge_df['timestamp'].apply(lambda time: time.dayofweek)
# <ipython-input-90-727d095ede5d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   task2merge_df['Hour'] = task2merge_df['timestamp'].apply(lambda time: time.hour)
#                 timestamp  new_bike_shares  temperature  feels_like_temp  \
# 0     2015-04-01 00:00:00              182          3.0              2.0
# 1     2015-04-01 01:00:00              138          3.0              2.5
# 2     2015-04-01 02:00:00              134          2.5              2.5
# 3     2015-04-01 03:00:00               72          2.0              2.0
# 4     2015-04-01 04:00:00               47          2.0              0.0
# ...                   ...              ...          ...              ...
# 17409 2017-03-01 19:00:00             1042          5.0              1.0
# 17410 2017-03-01 20:00:00              541          5.0              1.0
# 17411 2017-03-01 21:00:00              337          5.5              1.5
# 17412 2017-03-01 22:00:00              224          5.5              1.5
# 17413 2017-03-01 23:00:00              139          5.0              1.0
#
#        humidity  wind_speed  is_weekend  Year  Month  Day_of_Week  ...  \
# 0          93.0         6.0           1  2015      4            2  ...
# 1          93.0         5.0           1  2015      4            2  ...
# 2          96.5         0.0           1  2015      4            2  ...
# 3         100.0         0.0           1  2015      4            2  ...
# 4          93.0         6.5           1  2015      4            2  ...
# ...         ...         ...         ...   ...    ...          ...  ...
# 17409      81.0        19.0           0  2017      3            2  ...
# 17410      81.0        21.0           0  2017      3            2  ...
# 17411      78.5        24.0           0  2017      3            2  ...
# 17412      76.0        23.0           0  2017      3            2  ...
# 17413      76.0        22.0           0  2017      3            2  ...
#
#        Wednesday  Wednesday  Wednesday  Wednesday  Wednesday  Wednesday  \
# 0            NaN        NaN        NaN        NaN        NaN        NaN
# 1            NaN        NaN        NaN        NaN        NaN        NaN
# 2            NaN        NaN        NaN        NaN        NaN        NaN
# 3            NaN        NaN        NaN        NaN        NaN        NaN
# 4            NaN        NaN        NaN        NaN        NaN        NaN
# ...          ...        ...        ...        ...        ...        ...
# 17409        NaN        NaN        NaN        NaN        NaN        NaN
# 17410        NaN        NaN        NaN        NaN        NaN        NaN
# 17411        NaN        NaN        NaN        NaN        NaN        NaN
# 17412        NaN        NaN        NaN        NaN        NaN        NaN
# 17413        NaN        NaN        NaN        NaN        NaN        NaN
#
#        Wednesday  Wednesday  Wednesday  Wednesday
# 0            NaN        NaN        NaN        NaN
# 1            NaN        NaN        NaN        NaN
# 2            NaN        NaN        NaN        NaN
# 3            NaN        NaN        NaN        NaN
# 4            NaN        NaN        NaN        NaN
# ...          ...        ...        ...        ...
# 17409        NaN        NaN        NaN        NaN
# 17410        NaN        NaN        NaN        NaN
# 17411        NaN        NaN        NaN        NaN
# 17412        NaN        NaN        NaN        NaN
# 17413        NaN        NaN        NaN        NaN
#
# [17373 rows x 17385 columns]

# %%
GroupByHOUR=task2merge_df.groupby('Hour')

GroupByHOUR=GroupByHOUR['new_bike_shares'].describe()

GroupByHOUR=pd.DataFrame(GroupByHOUR)

#GroupByHOUR=GroupByHOUR.reset_index()

GroupByHOUR
# Out:
#       count         mean          std    min      25%     50%      75%     max
# Hour
# 0     724.0   290.609116   181.665548   29.0   158.00   239.0   366.00   982.0
# 1     722.0   201.167590   154.359959   20.0    94.00   150.5   246.00   932.0
# 2     713.0   137.652174   111.599264   20.0    60.00    95.0   176.00   684.0
# 3     698.0    96.862464    81.046852   20.0    41.00    63.0   132.00   510.0
# 4     714.0    73.859944    46.208959   21.0    43.00    58.0    87.75   286.0
# 5     720.0   110.841667    34.784933   24.0    87.00   110.0   134.00   351.0
# 6     726.0   466.626722   267.470619   21.0   156.25   544.5   668.00  1758.0
# 7     726.0  1468.745179   933.289868   47.0   286.00  1804.5  2197.50  5309.0
# 8     724.0  2882.823204  1778.304977   65.0   554.75  3684.0  4313.00  7531.0
# 9     727.0  1653.019257   697.719350  161.0   980.00  1849.0  2227.00  4832.0
# 10    725.0  1064.660690   330.138801  163.0   846.00  1050.0  1245.00  2760.0
# 11    727.0  1151.218707   500.193591  168.0   813.00  1071.0  1326.50  3027.0
# 12    729.0  1433.717421   608.049146  241.0  1011.00  1342.0  1687.00  3728.0
# 13    728.0  1505.739011   694.543230  150.0  1031.00  1388.0  1760.00  4341.0
# 14    728.0  1472.004121   735.916764  132.0   965.50  1324.5  1730.00  4214.0
# 15    729.0  1564.621399   742.489355  167.0  1051.00  1402.0  1847.00  4181.0
# 16    730.0  1869.801370   726.946465  148.0  1353.50  1776.5  2351.00  6033.0
# 17    728.0  2829.585165  1158.528966  151.0  2212.75  2820.5  3735.25  7860.0
# 18    728.0  2629.043956  1176.859948  140.0  1905.50  2633.0  3477.00  6913.0
# 19    727.0  1651.510316   715.802633  136.0  1183.50  1604.0  2168.00  4654.0
# 20    727.0  1059.781293   471.951450  116.0   748.00   989.0  1351.50  3156.0
# 21    726.0   741.249311   322.933763  106.0   510.00   705.0   918.00  2179.0
# 22    725.0   592.409655   243.523421   91.0   409.00   570.0   738.00  1545.0
# 23    722.0   439.652355   202.843926   82.0   296.00   398.5   553.75  1144.0

# %%
plt.plot(GroupByHOUR.index,GroupByHOUR['mean'],'-bo',color='g')
plt.title("Average distribution of bike shares by time of the day")
plt.ylabel('Average distribution of bike shares ')
plt.xlabel('HOUR')
plt.xticks(np.arange(0, 24))
# Out:
# ([<matplotlib.axis.XTick at 0x1ecb2b79b20>,
#   <matplotlib.axis.XTick at 0x1ecb2b4b2e0>,
#   <matplotlib.axis.XTick at 0x1ecb3f216d0>,
#   <matplotlib.axis.XTick at 0x1ecb3f4a430>,
#   <matplotlib.axis.XTick at 0x1ecb3f4a040>,
#   <matplotlib.axis.XTick at 0x1ecb3f4aca0>,
#   <matplotlib.axis.XTick at 0x1ecb3f521f0>,
#   <matplotlib.axis.XTick at 0x1ecb3f52700>,
#   <matplotlib.axis.XTick at 0x1ecb3f52c10>,
#   <matplotlib.axis.XTick at 0x1ecb3f57160>,
#   <matplotlib.axis.XTick at 0x1ecb3f57670>,
#   <matplotlib.axis.XTick at 0x1ecb3f57bb0>,
#   <matplotlib.axis.XTick at 0x1ecb3f577c0>,
#   <matplotlib.axis.XTick at 0x1ecb3f52850>,
#   <matplotlib.axis.XTick at 0x1ecb3f4a8e0>,
#   <matplotlib.axis.XTick at 0x1ecb3f60460>,
#   <matplotlib.axis.XTick at 0x1ecb3f60970>,
#   <matplotlib.axis.XTick at 0x1ecb3f60eb0>,
#   <matplotlib.axis.XTick at 0x1ecb3f66400>,
#   <matplotlib.axis.XTick at 0x1ecb3f66910>,
#   <matplotlib.axis.XTick at 0x1ecb3f66e20>,
#   <matplotlib.axis.XTick at 0x1ecb3f66640>,
#   <matplotlib.axis.XTick at 0x1ecb3f606a0>,
#   <matplotlib.axis.XTick at 0x1ecb3f571c0>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.plot(GroupByHOUR.index,GroupByHOUR['count'],'-bo',color='g')
plt.title("Total distribution of bike shares by time of the day")
plt.ylabel('Total distribution of bike shares ')
plt.xlabel('HOUR')
plt.xticks(np.arange(0, 24))
# Out:
# ([<matplotlib.axis.XTick at 0x1ecb55fdfd0>,
#   <matplotlib.axis.XTick at 0x1ecb55fdfa0>,
#   <matplotlib.axis.XTick at 0x1ecb55f8b20>,
#   <matplotlib.axis.XTick at 0x1ecb5622ca0>,
#   <matplotlib.axis.XTick at 0x1ecb562d1f0>,
#   <matplotlib.axis.XTick at 0x1ecb562d700>,
#   <matplotlib.axis.XTick at 0x1ecb562dc10>,
#   <matplotlib.axis.XTick at 0x1ecb5632160>,
#   <matplotlib.axis.XTick at 0x1ecb5632670>,
#   <matplotlib.axis.XTick at 0x1ecb5632b80>,
#   <matplotlib.axis.XTick at 0x1ecb56390d0>,
#   <matplotlib.axis.XTick at 0x1ecb5632340>,
#   <matplotlib.axis.XTick at 0x1ecb562d3d0>,
#   <matplotlib.axis.XTick at 0x1ecb5639430>,
#   <matplotlib.axis.XTick at 0x1ecb5639940>,
#   <matplotlib.axis.XTick at 0x1ecb5639e50>,
#   <matplotlib.axis.XTick at 0x1ecb563f3a0>,
#   <matplotlib.axis.XTick at 0x1ecb563f8b0>,
#   <matplotlib.axis.XTick at 0x1ecb563fdc0>,
#   <matplotlib.axis.XTick at 0x1ecb5645310>,
#   <matplotlib.axis.XTick at 0x1ecb563f580>,
#   <matplotlib.axis.XTick at 0x1ecb5639610>,
#   <matplotlib.axis.XTick at 0x1ecb5645490>,
#   <matplotlib.axis.XTick at 0x1ecb5645a00>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# <p style="color:red; font-weight:bold; font-size:xx-small">MARK: __%</p>
# <p style="color:red; font-weight:bold; font-size:xx-small">FEEDBACK: </p>

# %% [markdown]
# ### Requirement FR12 - Compare the distribution of bike shares by time of the week

# %%
GroupByweekday=task2merge_df.groupby('Day_of_Week')
GroupByweekday=GroupByweekday['new_bike_shares'].describe()

GroupByweekday=pd.DataFrame(GroupByweekday)

#GroupByHOUR=GroupByHOUR.reset_index()

GroupByweekday
# Out:
#               count         mean          std   min     25%    50%      75%  \
# Day_of_Week
# 0            2476.0  1162.997577  1145.466005  20.0  240.00  840.0  1685.00
# 1            2442.0  1229.585176  1168.332243  20.0  274.00  919.0  1750.00
# 2            2512.0  1203.468551  1128.894287  20.0  270.75  920.5  1728.25
# 3            2490.0  1203.308835  1119.311980  20.0  260.00  928.5  1744.50
# 4            2502.0  1167.616307  1058.165382  21.0  283.25  911.5  1723.75
# 5            2502.0  1040.958833   969.084293  22.0  267.25  720.5  1530.75
# 6            2449.0  1011.806860   968.614834  20.0  247.00  681.0  1497.00
#
#                 max
# Day_of_Week
# 0            7860.0
# 1            5342.0
# 2            5422.0
# 3            5295.0
# 4            5560.0
# 5            4919.0
# 6            5117.0

# %%
plt.plot(GroupByweekday.index,GroupByweekday['count'],'-bo',color='b')
plt.title("Total distribution of bike shares by days of the week")
plt.ylabel('Total distribution of bike shares ')
plt.xlabel('days_of _week')
# Out:
# Text(0.5, 0, 'days_of _week')

# %%
# add code here
plt.plot(GroupByweekday.index,GroupByweekday['mean'],'-bo',color='b')
plt.title("Average distribution of bike shares by days of the week")
plt.ylabel('Average distribution of bike shares ')
plt.xlabel('days_of _week')
# Out:
# Text(0.5, 0, 'days_of _week')

# %% [markdown]
# <p style="color:red; font-weight:bold; font-size:xx-small">MARK: __%</p>
# <p style="color:red; font-weight:bold; font-size:xx-small">FEEDBACK: </p>

# %% [markdown]
# ### Requirement FR13 - Investigate the effects of “feels like” temperature on the number of bike shares

# %%
Itask2merge_df
sns.lmplot(y='new_bike_shares',x='feels_like_temp',data=Itask2merge_df)

# %%
# add code here
Itask2merge_df=task2merge_df[["feels_like_temp","new_bike_shares"]]
GItask2merge_df=Itask2merge_df.groupby('feels_like_temp').mean()

GItask2merge_df=pd.DataFrame(GItask2merge_df, columns=['new_bike_shares'])

GItask2merge_df=GItask2merge_df.reset_index()

GItask2merge_df
# Out:
#     feels_like_temp  new_bike_shares
# 0              -6.0        77.000000
# 1              -5.5        37.000000
# 2              -5.0        84.000000
# 3              -4.5       655.000000
# 4              -4.0       556.833333
# ..              ...              ...
# 77             32.0      2016.142857
# 78             32.5      3164.333333
# 79             33.0      1542.000000
# 80             33.5      2454.000000
# 81             34.0      4610.500000
#
# [82 rows x 2 columns]

# %%
# %matplotlib inline

# Test for interraction between feels_like_temp and number of bike shares 
sns.lmplot(y='new_bike_shares',x='feels_like_temp',data=GItask2merge_df)
plt.title("linear Fits for correlation between the “feels_like_temp” temperature and the number of bike shares")
# Out:
# Text(0.5, 1.0, 'linear Fits for correlation between the “feels_like_temp” temperature and the number of bike shares')

# %% [markdown]
# <p style="color:red; font-weight:bold; font-size:xx-small">MARK: __%</p>
# <p style="color:red; font-weight:bold; font-size:xx-small">FEEDBACK: </p>

# %% [markdown]
# ### Requirement FR14 - Test the hypothesis that “feels like” temperature has an effect on the number of bike shares

# %%
# add code here
reg_mod = smf.ols(formula='new_bike_shares ~ feels_like_temp', data=GItask2merge_df).fit()
print(reg_mod.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        new_bike_shares   R-squared:                       0.786
# Model:                            OLS   Adj. R-squared:                  0.783
# Method:                 Least Squares   F-statistic:                     293.8
# Date:                Tue, 10 May 2022   Prob (F-statistic):           1.65e-28
# Time:                        10:11:11   Log-Likelihood:                -611.69
# No. Observations:                  82   AIC:                             1227.
# Df Residuals:                      80   BIC:                             1232.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         522.4724     73.392      7.119      0.000     376.417     668.528
# feels_like_temp    69.2586      4.041     17.140      0.000      61.217      77.300
# ==============================================================================
# Omnibus:                       19.349   Durbin-Watson:                   1.307
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.889
# Skew:                           0.766   Prob(JB):                     2.95e-10
# Kurtosis:                       6.240   Cond. No.                         28.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# <p style="color:red; font-weight:bold; font-size:xx-small">MARK: __%</p>
# <p style="color:red; font-weight:bold; font-size:xx-small">FEEDBACK: </p>

# %% [markdown]
# #  Coding Standards
# <p style="color:red; font-weight:bold; font-size:xx-small">MARK: __%</p>
# <p style="color:red; font-weight:bold; font-size:xx-small">FEEDBACK: </p>

# %% [markdown]
# # Process Development Report for Programming Task 2

# %% [markdown]
# add text here
#
#
# (b) INTERPRETATION OF RESULTS IN Q2.13 AND Q2.14 The scatter graph explains the linear association between the “feels_like_temp” temperature and the number of bike shares". Based on the size of the data, the output was muddled together.
# However, we could deduse from the graph there is a form of correlation between the factor "feels_like_temp" and number of bike shares. We therefore, use linear regression to fit the model so as to get a better interpretation.
#
# TRUE CORRELATION(NULL HYPOTHESIS):THEREIS *NO* ASSOCIATION BETWEEN “feels_like_temp” temperature and the number of bike shares"
# Ho: correlation = 0
# Hi: correlation ≠ 0
# α = 0.05
# From the above output in question 14, its seen that our R-squared is 0.786; this explain that 78.6% of the changes in the number_of_bike_shares can be explained by feels_like_temp. Following the assumption of hypothesis, i.e Reject the null hypothesis if P-value is less than α = 0.05. Our P-value< 2.2e-16 (0.00000000000000022) is relatively less than 0.05; hence we reject the null hypothesis and conclude that there is a significant relationship between “feels_like_temp” temperature and the number of bike shares". further investigations could be done on this analysis before making final diciesions depending on the prior intention of the researcher.

# %% [markdown]
# <p style="color:red; font-weight:bold; font-size:xx-small">MARK: __%</p>
# <p style="color:red; font-weight:bold; font-size:xx-small">FEEDBACK: </p>
